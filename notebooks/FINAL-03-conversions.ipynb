# %% [markdown]
# # Additional Conversions

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import ast

# %%
# Load data
def load_data(path):

    df = pd.read_csv(path)

    return df

# %%
recipe_df_filtered = load_data('recipe_df_eight_ingredients')

# %% [markdown]
# ### Coverting `NER_list` from list to string

# %%
def ingredient_parse_list(NER):
    return re.findall(r'"([^"]*)"',NER) # "([^"]*)" extracts the words within quotation marks

recipe_df_filtered['NER_list'] = recipe_df_filtered['NER'].apply(ingredient_parse_list)
print(recipe_df_filtered['NER_list'])
# Out:
# 0        [frozen corn, cream cheese, butter, garlic pow...
# 1        [broccoli, bacon, green onions, raisins, mayon...
# 2        [ground beef, tomato juice, oats, egg, onion, ...
# 3        [long, cooking oil, tomato sauce, water, brown...
# 4        [flour, baking powder, salt, butter, sugar, eg...
#                                ...
# 60812    [Salt, zucchini, Parmesan cheese, bread crumbs...
# 60813      [beets Juice, unsalted butter, orange, chervil]
# 60814    [broken wheat, water, jaggery grated, coconut ...
# 60815    [red Boysenberries, chocolate, whipped cream, ...
# 60816    [Bread, Grated cheese, Onions, Green peppers, ...
# Name: NER_list, Length: 60817, dtype: object

# %%
recipe_df_filtered['ingredient_list'] = pd.DataFrame(recipe_df_filtered['NER_list'])

# %%
print(type(recipe_df_filtered.loc[0,'ingredient_list']))
# Out:
# <class 'list'>

# %%
def list_to_string(s):

    str1 = ", "

    return (str1.join(s))

# %%
recipe_df_filtered['ingredient_list'] = pd.DataFrame(recipe_df_filtered['ingredient_list'].apply(list_to_string))
recipe_df_filtered.head()
# Out:
#                                 title  \
# 0                         Creamy Corn
# 1                      Broccoli Salad
# 2             Prize-Winning Meat Loaf
# 3  Corral Barbecued Beef Steak Strips
# 4                Mexican Cookie Rings
#
#                                          ingredients  \
# 0  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 1  ["1 large head broccoli (about 1 1/2 lb.)", "1...
# 2  ["1 1/2 lb. ground beef", "1 c. tomato juice",...
# 3  ["2 lb. round steak 1/2 to 3/4-inch thick, sli...
# 4  ["1 1/2 c. sifted flour", "1/2 tsp. baking pow...
#
#                                           directions  \
# 0  ["In a slow cooker, combine all ingredients. C...
# 1  ["Trim off large leaves of broccoli and remove...
# 2  ["Mix well.", "Press firmly into an 8 1/2 x 4 ...
# 3  ["Brown strips in cooking oil.", "Pour off dri...
# 4  ["Sift flour, baking powder and salt together....
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 1   www.cookbooks.com/Recipe-Details.aspx?id=50992  Gathered
# 2  www.cookbooks.com/Recipe-Details.aspx?id=923674  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=420402  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=364136  Gathered
#
#                                                  NER  serving_size  \
# 0  ["frozen corn", "cream cheese", "butter", "gar...             6
# 1  ["broccoli", "bacon", "green onions", "raisins...             6
# 2  ["ground beef", "tomato juice", "oats", "egg",...             8
# 3  ["long", "cooking oil", "tomato sauce", "water...             8
# 4  ["flour", "baking powder", "salt", "butter", "...            24
#
#                                             NER_list  ingredient_counter  \
# 0  [frozen corn, cream cheese, butter, garlic pow...                   6
# 1  [broccoli, bacon, green onions, raisins, mayon...                   7
# 2  [ground beef, tomato juice, oats, egg, onion, ...                   7
# 3  [long, cooking oil, tomato sauce, water, brown...                   8
# 4  [flour, baking powder, salt, butter, sugar, eg...                   8
#
#   Meal_Type                                    ingredient_list
# 0    dinner  frozen corn, cream cheese, butter, garlic powd...
# 1     salad  broccoli, bacon, green onions, raisins, mayonn...
# 2     lunch  ground beef, tomato juice, oats, egg, onion, p...
# 3    dinner  long, cooking oil, tomato sauce, water, brown ...
# 4   dessert  flour, baking powder, salt, butter, sugar, egg...

# %%
print(type(recipe_df_filtered.loc[0,'ingredient_list']))
# Out:
# <class 'str'>

# %% [markdown]
# ### Coverting `directions` from list to string

# %%
def preparation_parse_list(directions):
    try:
        # Safely evaluate the string representation of the list
        instructions_list = ast.literal_eval(directions)
        # Return a flat list of instructions
        return [instruction.strip() for instruction in instructions_list]
        # Or return a single string by joining
        # return ' '.join(instructions_list)  # If you want a single string
    except (ValueError, SyntaxError):
        return []  # Return an empty list in case of error

# Apply the function to your DataFrame
recipe_df_filtered['preparation_instructions'] = recipe_df_filtered['directions'].apply(preparation_parse_list)
print(recipe_df_filtered['preparation_instructions'])
# Out:
# 0        [In a slow cooker, combine all ingredients. Co...
# 1        [Trim off large leaves of broccoli and remove ...
# 2        [Mix well., Press firmly into an 8 1/2 x 4 1/2...
# 3        [Brown strips in cooking oil., Pour off drippi...
# 4        [Sift flour, baking powder and salt together.,...
#                                ...
# 60812    [Season pollock with salt and pepper., Place i...
# 60813    [Heat the oven to 375 degrees., Trim the leave...
# 60814    [(To make coconut lowfat milk finely grate a f...
# 60815    [About 3 hrs before serving or possibly early ...
# 60816    [Preheat oven to 350 degrees., Toast and cut t...
# Name: preparation_instructions, Length: 60817, dtype: object

# %%
print(type(recipe_df_filtered.loc[0,'preparation_instructions']))
# Out:
# <class 'list'>

# %%
recipe_df_filtered['preparation_instructions'] = pd.DataFrame(recipe_df_filtered['preparation_instructions'].apply(list_to_string))
recipe_df_filtered.head()
# Out:
#                                 title  \
# 0                         Creamy Corn
# 1                      Broccoli Salad
# 2             Prize-Winning Meat Loaf
# 3  Corral Barbecued Beef Steak Strips
# 4                Mexican Cookie Rings
#
#                                          ingredients  \
# 0  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 1  ["1 large head broccoli (about 1 1/2 lb.)", "1...
# 2  ["1 1/2 lb. ground beef", "1 c. tomato juice",...
# 3  ["2 lb. round steak 1/2 to 3/4-inch thick, sli...
# 4  ["1 1/2 c. sifted flour", "1/2 tsp. baking pow...
#
#                                           directions  \
# 0  ["In a slow cooker, combine all ingredients. C...
# 1  ["Trim off large leaves of broccoli and remove...
# 2  ["Mix well.", "Press firmly into an 8 1/2 x 4 ...
# 3  ["Brown strips in cooking oil.", "Pour off dri...
# 4  ["Sift flour, baking powder and salt together....
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 1   www.cookbooks.com/Recipe-Details.aspx?id=50992  Gathered
# 2  www.cookbooks.com/Recipe-Details.aspx?id=923674  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=420402  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=364136  Gathered
#
#                                                  NER  serving_size  \
# 0  ["frozen corn", "cream cheese", "butter", "gar...             6
# 1  ["broccoli", "bacon", "green onions", "raisins...             6
# 2  ["ground beef", "tomato juice", "oats", "egg",...             8
# 3  ["long", "cooking oil", "tomato sauce", "water...             8
# 4  ["flour", "baking powder", "salt", "butter", "...            24
#
#                                             NER_list  ingredient_counter  \
# 0  [frozen corn, cream cheese, butter, garlic pow...                   6
# 1  [broccoli, bacon, green onions, raisins, mayon...                   7
# 2  [ground beef, tomato juice, oats, egg, onion, ...                   7
# 3  [long, cooking oil, tomato sauce, water, brown...                   8
# 4  [flour, baking powder, salt, butter, sugar, eg...                   8
#
#   Meal_Type                                    ingredient_list  \
# 0    dinner  frozen corn, cream cheese, butter, garlic powd...
# 1     salad  broccoli, bacon, green onions, raisins, mayonn...
# 2     lunch  ground beef, tomato juice, oats, egg, onion, p...
# 3    dinner  long, cooking oil, tomato sauce, water, brown ...
# 4   dessert  flour, baking powder, salt, butter, sugar, egg...
#
#                             preparation_instructions
# 0  In a slow cooker, combine all ingredients. Cov...
# 1  Trim off large leaves of broccoli and remove t...
# 2  Mix well., Press firmly into an 8 1/2 x 4 1/2 ...
# 3  Brown strips in cooking oil., Pour off drippin...
# 4  Sift flour, baking powder and salt together., ...

# %%
print(type(recipe_df_filtered.loc[0,'preparation_instructions']))
# Out:
# <class 'str'>

# %% [markdown]
# ### Coverting `ingredients` from list to string

# %%
# Apply the function to your DataFrame
recipe_df_filtered['ingredient_measures'] = recipe_df_filtered['ingredients'].apply(preparation_parse_list)

# %%
print(type(recipe_df_filtered.loc[0,'ingredient_measures']))
# Out:
# <class 'list'>

# %%
recipe_df_filtered['ingredient_measures'] = pd.DataFrame(recipe_df_filtered['ingredient_measures'].apply(list_to_string))
recipe_df_filtered.head()
# Out:
#                                 title  \
# 0                         Creamy Corn
# 1                      Broccoli Salad
# 2             Prize-Winning Meat Loaf
# 3  Corral Barbecued Beef Steak Strips
# 4                Mexican Cookie Rings
#
#                                          ingredients  \
# 0  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 1  ["1 large head broccoli (about 1 1/2 lb.)", "1...
# 2  ["1 1/2 lb. ground beef", "1 c. tomato juice",...
# 3  ["2 lb. round steak 1/2 to 3/4-inch thick, sli...
# 4  ["1 1/2 c. sifted flour", "1/2 tsp. baking pow...
#
#                                           directions  \
# 0  ["In a slow cooker, combine all ingredients. C...
# 1  ["Trim off large leaves of broccoli and remove...
# 2  ["Mix well.", "Press firmly into an 8 1/2 x 4 ...
# 3  ["Brown strips in cooking oil.", "Pour off dri...
# 4  ["Sift flour, baking powder and salt together....
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 1   www.cookbooks.com/Recipe-Details.aspx?id=50992  Gathered
# 2  www.cookbooks.com/Recipe-Details.aspx?id=923674  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=420402  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=364136  Gathered
#
#                                                  NER  serving_size  \
# 0  ["frozen corn", "cream cheese", "butter", "gar...             6
# 1  ["broccoli", "bacon", "green onions", "raisins...             6
# 2  ["ground beef", "tomato juice", "oats", "egg",...             8
# 3  ["long", "cooking oil", "tomato sauce", "water...             8
# 4  ["flour", "baking powder", "salt", "butter", "...            24
#
#                                             NER_list  ingredient_counter  \
# 0  [frozen corn, cream cheese, butter, garlic pow...                   6
# 1  [broccoli, bacon, green onions, raisins, mayon...                   7
# 2  [ground beef, tomato juice, oats, egg, onion, ...                   7
# 3  [long, cooking oil, tomato sauce, water, brown...                   8
# 4  [flour, baking powder, salt, butter, sugar, eg...                   8
#
#   Meal_Type                                    ingredient_list  \
# 0    dinner  frozen corn, cream cheese, butter, garlic powd...
# 1     salad  broccoli, bacon, green onions, raisins, mayonn...
# 2     lunch  ground beef, tomato juice, oats, egg, onion, p...
# 3    dinner  long, cooking oil, tomato sauce, water, brown ...
# 4   dessert  flour, baking powder, salt, butter, sugar, egg...
#
#                             preparation_instructions  \
# 0  In a slow cooker, combine all ingredients. Cov...
# 1  Trim off large leaves of broccoli and remove t...
# 2  Mix well., Press firmly into an 8 1/2 x 4 1/2 ...
# 3  Brown strips in cooking oil., Pour off drippin...
# 4  Sift flour, baking powder and salt together., ...
#
#                                  ingredient_measures
# 0  2 (16 oz.) pkg. frozen corn, 1 (8 oz.) pkg. cr...
# 1  1 large head broccoli (about 1 1/2 lb.), 10 sl...
# 2  1 1/2 lb. ground beef, 1 c. tomato juice, 3/4 ...
# 3  2 lb. round steak 1/2 to 3/4-inch thick, slice...
# 4  1 1/2 c. sifted flour, 1/2 tsp. baking powder,...

# %%
print(type(recipe_df_filtered.loc[0,'ingredient_measures']))
# Out:
# <class 'str'>

# %% [markdown]
# ### Dropping redundant columns

# %%
recipe_df_filtered=recipe_df_filtered.drop(columns=['ingredients', 'directions', 'NER', 'NER_list'])

# %%
recipe_df_filtered.head()
# Out:
#                                 title  \
# 0                         Creamy Corn
# 1                      Broccoli Salad
# 2             Prize-Winning Meat Loaf
# 3  Corral Barbecued Beef Steak Strips
# 4                Mexican Cookie Rings
#
#                                               link    source  serving_size  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered             6
# 1   www.cookbooks.com/Recipe-Details.aspx?id=50992  Gathered             6
# 2  www.cookbooks.com/Recipe-Details.aspx?id=923674  Gathered             8
# 3  www.cookbooks.com/Recipe-Details.aspx?id=420402  Gathered             8
# 4  www.cookbooks.com/Recipe-Details.aspx?id=364136  Gathered            24
#
#    ingredient_counter Meal_Type  \
# 0                   6    dinner
# 1                   7     salad
# 2                   7     lunch
# 3                   8    dinner
# 4                   8   dessert
#
#                                      ingredient_list  \
# 0  frozen corn, cream cheese, butter, garlic powd...
# 1  broccoli, bacon, green onions, raisins, mayonn...
# 2  ground beef, tomato juice, oats, egg, onion, p...
# 3  long, cooking oil, tomato sauce, water, brown ...
# 4  flour, baking powder, salt, butter, sugar, egg...
#
#                             preparation_instructions  \
# 0  In a slow cooker, combine all ingredients. Cov...
# 1  Trim off large leaves of broccoli and remove t...
# 2  Mix well., Press firmly into an 8 1/2 x 4 1/2 ...
# 3  Brown strips in cooking oil., Pour off drippin...
# 4  Sift flour, baking powder and salt together., ...
#
#                                  ingredient_measures
# 0  2 (16 oz.) pkg. frozen corn, 1 (8 oz.) pkg. cr...
# 1  1 large head broccoli (about 1 1/2 lb.), 10 sl...
# 2  1 1/2 lb. ground beef, 1 c. tomato juice, 3/4 ...
# 3  2 lb. round steak 1/2 to 3/4-inch thick, slice...
# 4  1 1/2 c. sifted flour, 1/2 tsp. baking powder,...

# %% [markdown]
# ### Save data

# %%
recipe_df_filtered.to_csv('recipe_df_filtered_2.csv', index = False, sep =',', lineterminator='\n')
